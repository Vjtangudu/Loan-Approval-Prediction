# %%
#install libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

# %%
df = pd.read_csv('Dataset.csv')
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
df.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status
# 609             1.0         Rural           Y
# 610             1.0         Rural           Y
# ...

# %%
df.shape
# Out:
# (614, 13)

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
## check outliers
plt.figure(figsize=(12,8)) ##height and width of the boxplot
sns.boxenplot(data= df)
# Out:
# <Axes: >

# %%
## filling the null values of numerical datatype 
df['LoanAmount'] = df['LoanAmount'].fillna(df['LoanAmount'].median())
df['Loan_Amount_Term'] = df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mean())
df['Credit_History'] = df['Credit_History'].fillna(df['Credit_History'].mean())

# %%
## filling the null values of object datatype 
df['Gender'] = df['Gender'].fillna(df['Gender'].mode()[0])
df['Married'] = df['Married'].fillna(df['Married'].mode()[0])
df['Dependents'] = df['Dependents'].fillna(df['Dependents'].mode()[0])
df['Self_Employed'] = df['Self_Employed'].fillna(df['Self_Employed'].mode()[0])

# %%
df.isnull().sum() #check null items
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df['Gender'].mode()[0] #mode
# Out:
# 'Male'

# %%
df['LoanAmount'].median() #median value
# Out:
# 128.0

# %%
df['LoanAmount'].mean() ##mean value
# Out:
# 145.75244299674267

# %%
print('Number of people who took loan by gender')
print(df['Gender'].value_counts()) #returns count of each value under gender
sns.countplot(x='Gender',data=df, palette='Set1') #graph of count vs gender
# Out:
# Number of people who took loan by gender
# Male      502
# Female    112
# Name: Gender, dtype: int64
# <Axes: xlabel='Gender', ylabel='count'>

# %%
print('Number of people who took loan by Maratial Status')
print(df['Married'].value_counts()) 
sns.countplot(x='Married',data=df, palette='Set2')
# Out:
# Number of people who took loan by Maratial Status
# Yes    401
# No     213
# Name: Married, dtype: int64
# <Axes: xlabel='Married', ylabel='count'>

# %%
print('Number of people who took loan by Education')
print(df['Education'].value_counts()) 
sns.countplot(x='Education',data=df, palette='Set3')
# Out:
# Number of people who took loan by Education
# Graduate        480
# Not Graduate    134
# Name: Education, dtype: int64
# <Axes: xlabel='Education', ylabel='count'>

# %%
corr = df.corr()
plt.figure(figsize=(15,10))
sns.heatmap(corr, annot= True, cmap='BuPu')
# Out:
# <Axes: >

# %%
corr = df.corr()
corr
# Out:
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# ApplicantIncome           1.000000          -0.116605    0.565181
# CoapplicantIncome        -0.116605           1.000000    0.189218
# LoanAmount                0.565181           0.189218    1.000000
# Loan_Amount_Term         -0.045242          -0.059675    0.039235
# Credit_History           -0.014477          -0.001665   -0.007031
#
#                    Loan_Amount_Term  Credit_History
# ApplicantIncome           -0.045242       -0.014477
# CoapplicantIncome         -0.059675       -0.001665
# LoanAmount                 0.039235       -0.007031
# Loan_Amount_Term           1.000000        0.001395
# Credit_History             0.001395        1.000000

# %%
#Total applicant Income
df['Total_Income'] = df['ApplicantIncome'] + df['CoapplicantIncome']
df.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status  Total_Income
# 609             1.0         Rural           Y        2900.0
# ...

# %%
#Apply log transformation
df['ApplicantIncomeLog'] = np.log(df['ApplicantIncome'] + 1)
sns.displot(df['ApplicantIncomeLog'])

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status  Total_Income  ApplicantIncomeLog
# 0             1.0         Urban           Y        5849.0            8.674197
# ...

# %%
#Apply log transformation
df['LoanAmountLog'] = np.log(df['LoanAmount'] + 1)
sns.displot(df['LoanAmountLog'])

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status  Total_Income  ApplicantIncomeLog  \
# ...

# %%
#Apply log transformation
df['Loan_Amount_Term_Log'] = np.log(df['Loan_Amount_Term'] + 1)
sns.displot(df['Loan_Amount_Term_Log'])

# %%
df.tail()
# Out:
#       Loan_ID  Gender Married Dependents Education Self_Employed  \
# 609  LP002978  Female      No          0  Graduate            No
# 610  LP002979    Male     Yes         3+  Graduate            No
# 611  LP002983    Male     Yes          1  Graduate            No
# 612  LP002984    Male     Yes          2  Graduate            No
# 613  LP002990  Female      No          0  Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 609             2900                0.0        71.0             360.0
# 610             4106                0.0        40.0             180.0
# 611             8072              240.0       253.0             360.0
# 612             7583                0.0       187.0             360.0
# 613             4583                0.0       133.0             360.0
#
#      Credit_History Property_Area Loan_Status  Total_Income  \
# 609             1.0         Rural           Y        2900.0
# ...

# %%
#Apply log transformation
df['Total_Income_Log'] = np.log(df['Total_Income'] + 1)
sns.displot(df['Total_Income_Log'])

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0       128.0             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status  Total_Income  ApplicantIncomeLog  \
# ...

# %%
#drop unnessary columns
cols = ['ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term','Loan_ID']
df = df.drop(columns= cols, axis= 1)
df.head()
# Out:
#   Gender Married Dependents     Education Self_Employed  Credit_History  \
# 0   Male      No          0      Graduate            No             1.0
# 1   Male     Yes          1      Graduate            No             1.0
# 2   Male     Yes          0      Graduate           Yes             1.0
# 3   Male     Yes          0  Not Graduate            No             1.0
# 4   Male      No          0      Graduate            No             1.0
#
#   Property_Area Loan_Status  Total_Income  ApplicantIncomeLog  LoanAmountLog  \
# 0         Urban           Y        5849.0            8.674197       4.859812
# 1         Rural           N        6091.0            8.430327       4.859812
# 2         Urban           Y        3000.0            8.006701       4.204693
# 3         Urban           Y        4941.0            7.857094       4.795791
# 4         Urban           Y        6000.0            8.699681       4.955827
#
#    Loan_Amount_Term_Log  Total_Income_Log
# ...

# %%
#Encoding converstion of categorical into numrical values
#Encoding Technique: Label Encoding, One Hot Encoding

from sklearn.preprocessing import LabelEncoder
cols = ['Gender', 'Married', 'Education', 'Dependents', 'Self_Employed', 'Property_Area', 'Loan_Status']
le = LabelEncoder()
for col in cols:
    df[col] = le.fit_transform(df[col])

df.head()
# Out:
#    Gender  Married  Dependents  Education  Self_Employed  Credit_History  \
# 0       1        0           0          0              0             1.0
# 1       1        1           1          0              0             1.0
# 2       1        1           0          0              1             1.0
# 3       1        1           0          1              0             1.0
# 4       1        0           0          0              0             1.0
#
#    Property_Area  Loan_Status  Total_Income  ApplicantIncomeLog  \
# 0              2            1        5849.0            8.674197
# 1              0            0        6091.0            8.430327
# 2              2            1        3000.0            8.006701
# 3              2            1        4941.0            7.857094
# 4              2            1        6000.0            8.699681
#
#    LoanAmountLog  Loan_Amount_Term_Log  Total_Income_Log
# 0       4.859812              5.888878          8.674197
# ...

# %%
df.dtypes
# Out:
# Gender                    int32
# Married                   int32
# Dependents                int32
# Education                 int32
# Self_Employed             int32
# Credit_History          float64
# Property_Area             int32
# Loan_Status               int32
# Total_Income            float64
# ApplicantIncomeLog      float64
# LoanAmountLog           float64
# Loan_Amount_Term_Log    float64
# Total_Income_Log        float64
# dtype: object

# %%
#Split Independent and Dependent 
x = df.drop(columns='Loan_Status', axis=1) #independent
y = df['Loan_Status']

# %%
x
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  Credit_History  \
# 0         1        0           0          0              0             1.0
# 1         1        1           1          0              0             1.0
# 2         1        1           0          0              1             1.0
# 3         1        1           0          1              0             1.0
# 4         1        0           0          0              0             1.0
# ..      ...      ...         ...        ...            ...             ...
# 609       0        0           0          0              0             1.0
# 610       1        1           3          0              0             1.0
# 611       1        1           1          0              0             1.0
# 612       1        1           2          0              0             1.0
# 613       0        0           0          0              1             0.0
#
# ...

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 609    1
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Loan_Status, Length: 614, dtype: int32

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.25,random_state=42)

# %%
#logistic Regression
model1 = LogisticRegression()
model1.fit(x_train,y_train)
y_pred_model1 = model1.predict(x_test)
accuracy = accuracy_score(y_test,y_pred_model1)

# %%
accuracy*100
# Out:
# 64.93506493506493

# %%
score = cross_val_score(model1, x, y, cv = 5)
score
# Out:
# array([0.81300813, 0.77235772, 0.67479675, 0.86178862, 0.68852459])

# %%
np.mean(score)*100
# Out:
# 76.20951619352259

# %%
#Decision Tree Classifier

model2 = DecisionTreeClassifier()
model2.fit(x_train, y_train)
y_pred_model2 = model2.predict(x_test)
accuracy = accuracy_score(y_pred_model2,y_test)
print("Accuracy score of Decision Tree Model: ",accuracy*100)
# Out:
# Accuracy score of Decision Tree Model:  73.37662337662337

# %%
score = cross_val_score(model2, x, y, cv = 5)
print('Cross validation score of Decision Tree: ',np.mean(score)*100)
# Out:
# Cross validation score of Decision Tree:  70.68505930960949

# %%
#RandomForest Classifier

model3 = RandomForestClassifier()
model3.fit(x_train, y_train)
y_pred_model3 = model3.predict(x_test)
accuracy = accuracy_score(y_pred_model3,y_test)
print("Accuracy score of RandomForest Model: ",accuracy*100)
# Out:
# Accuracy score of RandomForest Model:  78.57142857142857

# %%
score = cross_val_score(model3, x, y, cv = 5)
print('Cross validation score of RandomForest: ',np.mean(score)*100)
# Out:
# Cross validation score of RandomForest:  78.99506863921098

# %%
#KNeighbor Model

model4 = KNeighborsClassifier(n_neighbors=5)
model4.fit(x_train, y_train)
y_pred_model4 = model4.predict(x_test)
accuracy = accuracy_score(y_pred_model4,y_test)
print("Accuracy score of KNeighbors Model: ",accuracy*100)
# Out:
# Accuracy score of KNeighbors Model:  59.09090909090909

# %%
score = cross_val_score(model4, x, y, cv = 5)
print('Cross validation score of KNeighbors: ',np.mean(score)*100)
# Out:
# Cross validation score of KNeighbors:  61.40077302412368

# %%
from sklearn.metrics import classification_report

def generate_classification_report(model_name,y_test,y_pred):
    report = classification_report(y_test,y_pred)
    print(f'Classification Report for {model_name}: \n{report}\n')

generate_classification_report(model1,y_test,y_pred_model1)
generate_classification_report(model1,y_test,y_pred_model2)
generate_classification_report(model1,y_test,y_pred_model3)
generate_classification_report(model1,y_test,y_pred_model4)
# Out:
# Classification Report for LogisticRegression():
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        54
#            1       0.65      1.00      0.79       100
#
#     accuracy                           0.65       154
#    macro avg       0.32      0.50      0.39       154
# weighted avg       0.42      0.65      0.51       154
#
#
# Classification Report for LogisticRegression():
#               precision    recall  f1-score   support
#
#            0       0.64      0.54      0.59        54
#            1       0.77      0.84      0.80       100
#
#     accuracy                           0.73       154
#    macro avg       0.71      0.69      0.69       154
# weighted avg       0.73      0.73      0.73       154
#
#
# Classification Report for LogisticRegression():
#               precision    recall  f1-score   support
#
#            0       0.84      0.48      0.61        54
# ...

# %%
df['Loan_Status'].value_counts()
# Out:
# 1    422
# 0    192
# Name: Loan_Status, dtype: int64

# %%
pip install -U imbalanced-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#over sampling
from imblearn.over_sampling import RandomOverSampler

# %%
oversample = RandomOverSampler(random_state=42)
x_resampled, y_resampled = oversample.fit_resample(x,y)

df_resampled = pd.concat([pd.DataFrame(x_resampled,columns=x.columns),pd.Series(y_resampled,name='Loan_Status')],axis=1)

# %%
x_resampled
# Out:
#      Gender  Married  Dependents  Education  Self_Employed  Credit_History  \
# 0         1        0           0          0              0        1.000000
# 1         1        1           1          0              0        1.000000
# 2         1        1           0          0              1        1.000000
# 3         1        1           0          1              0        1.000000
# 4         1        0           0          0              0        1.000000
# ..      ...      ...         ...        ...            ...             ...
# 839       1        1           3          1              0        1.000000
# 840       1        1           1          0              0        0.842199
# 841       1        1           1          0              0        0.000000
# 842       1        1           2          1              0        0.000000
# 843       1        0           0          0              0        0.000000
#
# ...

# %%
y_resampled
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 839    0
# 840    0
# 841    0
# 842    0
# 843    0
# Name: Loan_Status, Length: 844, dtype: int32

# %%
y_resampled.value_counts()
# Out:
# 1    422
# 0    422
# Name: Loan_Status, dtype: int64

# %%
x_resampled_train, x_resampled_test, y_resampled_train, y_resampled_test = train_test_split(x_resampled,y_resampled,test_size=0.25,random_state=42)

# %%
#logistic Regression
model1 = LogisticRegression()
model1.fit(x_resampled_train,y_resampled_train)
y_pred_model1 = model1.predict(x_resampled_test)
accuracy = accuracy_score(y_resampled_test,y_pred_model1)
accuracy*100
# Out:
# 67.29857819905213

# %%
#Decision Tree Classifier

model2 = DecisionTreeClassifier()
model2.fit(x_resampled_train, y_resampled_train)
y_pred_model2 = model2.predict(x_resampled_test)
accuracy = accuracy_score(y_pred_model2,y_resampled_test)
print("Accuracy score of Decision Tree Model: ",accuracy*100)
# Out:
# Accuracy score of Decision Tree Model:  81.04265402843602

# %%
#RandomForest Classifier

model3 = RandomForestClassifier()
model3.fit(x_resampled_train, y_resampled_train)
y_pred_model3 = model3.predict(x_resampled_test)
accuracy = accuracy_score(y_pred_model3,y_resampled_test)
print("Accuracy score of RandomForest Model: ",accuracy*100)
# Out:
# Accuracy score of RandomForest Model:  88.15165876777252

# %%
#KNeighbor Model

model4 = KNeighborsClassifier(n_neighbors=5)
model4.fit(x_resampled_train, y_resampled_train)
y_pred_model4 = model4.predict(x_resampled_test)
accuracy = accuracy_score(y_pred_model4,y_resampled_test)
print("Accuracy score of KNeighbors Model: ",accuracy*100)
# Out:
# Accuracy score of KNeighbors Model:  58.767772511848335

# %%
from sklearn.metrics import classification_report

def generate_classification_report(model_name,y_resampled_test,y_pred):
    report = classification_report(y_resampled_test,y_pred)
    print(f'Classification Report for {model_name}: \n{report}\n')

generate_classification_report(model1,y_resampled_test,y_pred_model1)
generate_classification_report(model1,y_resampled_test,y_pred_model2)
generate_classification_report(model1,y_resampled_test,y_pred_model3)
generate_classification_report(model1,y_resampled_test,y_pred_model4)
# Out:
# Classification Report for LogisticRegression():
#               precision    recall  f1-score   support
#
#            0       0.78      0.54      0.64       114
#            1       0.61      0.82      0.70        97
#
#     accuracy                           0.67       211
#    macro avg       0.70      0.68      0.67       211
# weighted avg       0.70      0.67      0.67       211
#
#
# Classification Report for LogisticRegression():
#               precision    recall  f1-score   support
#
#            0       0.80      0.86      0.83       114
#            1       0.82      0.75      0.78        97
#
#     accuracy                           0.81       211
#    macro avg       0.81      0.81      0.81       211
# weighted avg       0.81      0.81      0.81       211
#
#
# Classification Report for LogisticRegression():
#               precision    recall  f1-score   support
#
#            0       0.91      0.87      0.89       114
# ...
